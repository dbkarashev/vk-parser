# %% [markdown]
# <a href="https://colab.research.google.com/github/dbkarashev/vk-parser/blob/main/vkparser0.0.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ВК-парсер

# %% [markdown]
# ### `Объявляем необходимые функции`

# %%
# %pip install vk
# Out:
# Collecting vk
#   Downloading vk-2.0.2.tar.gz (7.0 kB)
# Requirement already satisfied: requests<3.0,>=2.8 in /usr/local/lib/python3.7/dist-packages (from vk) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8->vk) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8->vk) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8->vk) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8->vk) (1.24.3)
# Building wheels for collected packages: vk
#   Building wheel for vk (setup.py) ... done
#   Created wheel for vk: filename=vk-2.0.2-py3-none-any.whl size=8275 sha256=3373f2b671120fd4c6eca182206e563cab62651a62c990577e90445628850208
#   Stored in directory: /root/.cache/pip/wheels/7b/d0/2b/d07628ebced43577b8001d0c9d716f972059535bbaadb1eb9d
# Successfully built vk
# Installing collected packages: vk
# Successfully installed vk-2.0.2

# %%
import vk  # Импортируем модуль vk
import numpy as np

# %%
import vk  # Импортируем модуль vk

def get_members(groupid):  # Функция формирования базы участников сообщества в виде списка
  pass

def save_data(data, filename):  # Функция сохранения базы в txt файле
  pass

def friends_of_members(subs_ids):    # Функция которая по айди пользователся возвращает массив его друзей
  pass


if __name__ == "__main__": 
    token = "37e0a52137e0a52137e0a521c8379912e4337e037e0a521568a3a0c21490ce308276d39"  # Сервисный ключ доступа
    session = vk.Session(access_token=token)  # Авторизация
    vk_api = vk.API(session)

# %%
def get_members(groupid):
    first = vk_api.groups.getMembers(group_id=groupid, v=5.92)  # Первое выполнение метода
    data = first["items"]  # Присваиваем переменной первую тысячу id'шников
    count = first["count"] // 1000  # Присваиваем переменной количество тысяч участников
    # С каждым проходом цикла смещение offset увеличивается на тысячу
    # и еще тысяча id'шников добавляется к нашему списку.
    for i in range(1, count+1):  
        data = data + vk_api.groups.getMembers(group_id=groupid, v=5.92, offset=i*1000)["items"]
    return data

# %%
def save_data(data, filename):  # Функция сохранения базы в txt файле
    with open(filename, "w") as file:  # Открываем файл на запись
        # Записываем каждый id'шник в новой строке,
        # добавляя в начало "vk.com/id", а в конец перенос строки.
        for item in data:   
            file.write("vk.com/id" + str(item) + "\n")

# %% [markdown]
# ## `Составляем словарь друзей каждого участника`

# %% [markdown]
# ### Общажный повар

# %%
subs = get_members("tsufood") # список подписчиков
save_data(subs, "tsufood_subs.txt")
N=len(subs)

# %%
print(subs)
# Out:
# [176810, 195921, 230052, 236985, 394696, 426271, 864562, 913386, 1082911, 1089941, 1303173, 1391786, 1439819, 1493119, 1580665, 2023239, 2057651, 2292527, 2425364, 2478713, 2548379, 2623734, 2624912, 2691949, 2830165, 3132719, 3210129, 3326032, 3465241, 3557609, 3571277, 3608153, 3752575, 3968633, 4030817, 4077424, 4125910, 4325428, 4413758, 4628012, 4677887, 4693982, 5036655, 5230610, 5345061, 5372118, 5682025, 5802072, 5939929, 6150369, 6266239, 6701055, 6739443, 6771697, 6848241, 6855510, 7056741, 7193068, 7557141, 7579867, 8415096, 8633419, 8662443, 8715147, 8847650, 8861263, 8893663, 9010170, 9207330, 9603954, 9659110, 9691231, 9741171, 9780122, 9806315, 9815425, 10047713, 10118236, 10175977, 10294855, 10313932, 10570901, 11028825, 11066134, 11242211, 11323610, 11532129, 11559589, 11616303, 11690167, 11716453, 11770459, 12253869, 12267686, 12329187, 12381276, 12514235, 12929595, 13003049, 13208500, 13231612, 13352288, 13368398, 13431840, 13658752, 14185686, 14188292, 14262009, 14681250, 14758269, 15016332, 15204695, 15258621, 15434288, 15959619, 16067148, 16260635, 16322488, 17082167, 17433667, 17453149, 17454060, 17567903, 17745117, 17756055, 17953568, 18269209, 18272452, 18641087, 19030255, 19215524, 19386599, 19547645, 19689542, 19736323, 20005038, 20078963, 20126524, 20271167, 20304012, 20386794, 20393068, 20393496, 21017921, 21100564, 21151540, 21206316, 21209612, 21760829, 21781432, 21837734, 21888696, 22138325, 22231065, 22545004, 22556882, 22567247, 22710411, 22779691, 23073117, 23119968, 23334030, 23445160, 23465253, 23467095, 23622675, 23882546, 24014306, 24022971, 24090208, 24161141, 24175455, 24178826, 24448991, 24508136, 24592446, 24754561, 25048235, 25159882, 25310346, 25560168, 25561505, 25724507, 25779715, 26213889, 26246726, 26264336, 26497366, 26617436, 26988152, 27147913, 27170131, 27524083, 28081802, 28687680, 28944561, 29108410, 29143540, 29192930, 29711648, 29730255, 29783276, 29840973, 30009405, 30284968, 30373809, 30450239, 30515909, 30766356, 31037801, 31272928, 31358664, 31394003, 31534145, 32361125, 33078637, 33143455, 33274684, 33352767, 33363287, 33372930, 33633742, 34000830, 34070542, 34124691, 34166268, 34174042, 34376957, 34522224, 34549752, 34635064, 34681160, 34772535, 34799465, 34808632, 34884585, 35179445, 35865813, 36066442, 36180085, 36246546, 36447074, 36451869, 36711954, 37099515, 37191080, 37286568, 37582178, 37659552, 37856160, 38351183, 38351269, 38937484, 39522464, 39654366, 39667109, 39786640, 39884249, 39951859, 39960795, 40071957, 40111857, 40178403, 40649580, 40870537, 40951230, 41367224, 41677014, 41801183, 41896531, 42096510, 42368373, 42940615, 43209980, 43223966, 43226928, 43266059, 43419512, 43784220, 43809728, 43852126, 44055120, 44130240, 44151389, 44401689, 44496950, 44517872, 44528082, 44685981, 44967210, 45064573, 45143652, 45241509, 45343065, 45835766, 45959756, 46074095, 46469667, 46560284, 46848885, 46944087, 48339517, 48531196, 49015073, 49208627, 49355238, 49436788, 49777816, 49805893, 49864962, 50101709, 50279409, 50398486, 50857058, 50963922, 51029615, 51204968, 51209867, 51307159, 51318530, 51391747, 51823454, 51827487, 51842571, 52011424, 52168477, 52298804, 52394881, 52416798, 52797129, 53298766, 53397140, 53521754, 53720302, 53757848, 55125871, 55520832, 55725160, 55871442, 56171613, 56432399, 56750989, 56804539, 57312422, 57315790, 57316549, 57316895, 57447327, 58049811, 58192620, 58328628, 58357001, 58414088, 58993140, 59153871, 59277263, 59487600, 59585596, 59726795, 59985010, 60183368, 60263091, 60296470, 60885605, 60889900, 61222194, 61847496, 61850440, 62224559, 62311664, 62841212, 62907908, 63479463, 63488228, 63616967, 63625567, 63712392, 63735667, 64107345, 64172275, 64189914, 64642581, 64790498, 64918315, 64939768, 64956049, 65084380, 65106224, 65247884, 65411626, 65420173, 65497377, 65534730, 65535695, 65626872, 65778345, 65940494, 65964030, 66288247, 66405556, 66600177, 67282876, 67417823, 67425870, 67633622, 67897028, 68033129, 68340402, 683 ...

# %%
from vk import *

# %%
def friends_of_member(subs_id) :
    fom = []
      #fom это друзья участника
    try:
        fom.append(vk_api.friends.get(user_id=int(subs_id), v=5.131)['items'])
    except: #VkAPIError:
        fom.append([])
    return fom

# %%
friends_of_all_members = {}
for i in range(len(subs)):
    friends_of_all_members[subs[i]] = friends_of_member(subs[i])

# %%
friends_of_all_members_matrix = np.ndarray(shape=(N, N), dtype=np.object)

# %%
for i in range(len(subs)):
  for j in range(len(subs)):
     friends_of_all_members_matrix[i][j] = len(set(friends_of_all_members[subs[i]][0])&set(friends_of_all_members[subs[j]][0]))

# %%
for i in range(20):
  j=4
  print(i, subs[i])
  A[i][j] = len(set(friends_of_all_members[subs[i]][0])&set(friends_of_all_members[subs[j]][0]))

# %% [markdown]
# ### МНМЦ ТГУ

# %%
subs = get_members("cpdittsu") # список подписчиков
save_data(subs, "cpdittsu_subs.txt")

# %%
friends_of_all_members = {}
for i in range(len(subs)):
    friends_of_all_members[subs[i]] = friends_of_member(subs[i])

# %%
friends_of_all_members

# %%
common_friends = list(set(friends_of_all_members[75156][0]) & set(friends_of_all_members[382491][0]))
common_friends
# Out:
# []
